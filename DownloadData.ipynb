# %%
import os
import sys
import pandas as pd
import glob
from PIL import Image
import shutil

# %% [markdown]
# ## Train data

# %%
label_path = '/groups/CS156b/data/student_labels/train2023.csv'
df = pd.read_csv(label_path)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 label_path = '/groups/CS156b/data/student_labels/train2023.csv'
# ----> 2 df = pd.read_csv(label_path)
#       3 df.head()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
image_paths = df['Path'][:-1]
image_paths_subset = image_paths[:25]
image_paths_subset
# Out:
# 0      train/pid50512/study1/view1_frontal.jpg
# 1      train/pid21580/study2/view1_frontal.jpg
# 2      train/pid21580/study1/view1_frontal.jpg
# 3      train/pid21580/study1/view2_lateral.jpg
# 4      train/pid33839/study1/view1_frontal.jpg
# 5      train/pid17532/study1/view1_frontal.jpg
# 6      train/pid17532/study1/view2_lateral.jpg
# 7      train/pid05208/study1/view1_frontal.jpg
# 8      train/pid35409/study1/view1_frontal.jpg
# 9      train/pid35409/study2/view1_frontal.jpg
# 10     train/pid27777/study1/view1_frontal.jpg
# 11     train/pid27777/study2/view1_frontal.jpg
# 12     train/pid50113/study1/view1_frontal.jpg
# 13     train/pid50113/study1/view2_lateral.jpg
# 14    train/pid18261/study13/view1_frontal.jpg
# 15    train/pid18261/study13/view2_lateral.jpg
# 16     train/pid18261/study1/view1_frontal.jpg
# 17     train/pid18261/study5/view1_frontal.jpg
# 18     train/pid18261/study7/view1_frontal.jpg
# 19     train/pid18261/study4/view1_frontal.jpg
# ...

# %%
prefix = '/groups/CS156b/data/train/'
dest_dir = '/groups/CS156b/2024/BroadBahnMi/data/train/images/'
for i, path in enumerate(image_paths_subset):
    pid = path.split('/')[1]
    fullpath = prefix + pid
    if (not os.path.isdir(dest_dir + pid)):
        print(fullpath, dest_dir)
        shutil.copytree(fullpath, dest_dir + pid)
# Out:
# /groups/CS156b/data/train/pid21580 /groups/CS156b/2024/BroadBahnMi/data/train/images/
# /groups/CS156b/data/train/pid33839 /groups/CS156b/2024/BroadBahnMi/data/train/images/
# /groups/CS156b/data/train/pid17532 /groups/CS156b/2024/BroadBahnMi/data/train/images/
# /groups/CS156b/data/train/pid05208 /groups/CS156b/2024/BroadBahnMi/data/train/images/
# /groups/CS156b/data/train/pid35409 /groups/CS156b/2024/BroadBahnMi/data/train/images/
# /groups/CS156b/data/train/pid27777 /groups/CS156b/2024/BroadBahnMi/data/train/images/
# /groups/CS156b/data/train/pid50113 /groups/CS156b/2024/BroadBahnMi/data/train/images/
# /groups/CS156b/data/train/pid18261 /groups/CS156b/2024/BroadBahnMi/data/train/images/

# %%
df = df[:100]
df
# Out:
#     Unnamed: 0.1  Unnamed: 0                                     Path     Sex  \
# 0              0           0  train/pid50512/study1/view1_frontal.jpg  Female
# 1              1           1  train/pid21580/study2/view1_frontal.jpg  Female
# 2              2           2  train/pid21580/study1/view1_frontal.jpg  Female
# 3              3           3  train/pid21580/study1/view2_lateral.jpg  Female
# 4              4           4  train/pid33839/study1/view1_frontal.jpg    Male
# ..           ...         ...                                      ...     ...
# 95            95         118  train/pid29701/study4/view1_frontal.jpg  Female
# 96            96         119  train/pid29701/study3/view1_frontal.jpg  Female
# 97            97         120  train/pid29701/study7/view1_frontal.jpg  Female
# 98            98         121  train/pid29701/study9/view1_frontal.jpg  Female
# 99            99         122  train/pid29701/study6/view1_frontal.jpg  Female
#
# ...

# %%
df.to_csv('/groups/CS156b/2024/BroadBahnMi/data/train/labels/labels.csv', sep='\t')

# %% [markdown]
# ## Test data

# %%
test_df = pd.read_csv('/groups/CS156b/data/student_labels/test_ids.csv')[:10]
test_df.head()
# Out:
#    Id                                    Path
# 0  18  test/pid56785/study1/view1_frontal.jpg
# 1  19  test/pid56785/study1/view2_lateral.jpg
# 2  44  test/pid57943/study1/view1_frontal.jpg
# 3  45  test/pid57943/study2/view1_frontal.jpg
# 4  57  test/pid54805/study1/view1_frontal.jpg

# %%
test_df.to_csv('/groups/CS156b/2024/BroadBahnMi/data/test/ids.csv', sep='\t')

# %%
test_imgs_paths = test_df['Path']
test_imgs_paths
# Out:
# 0    test/pid56785/study1/view1_frontal.jpg
# 1    test/pid56785/study1/view2_lateral.jpg
# 2    test/pid57943/study1/view1_frontal.jpg
# 3    test/pid57943/study2/view1_frontal.jpg
# 4    test/pid54805/study1/view1_frontal.jpg
# 5    test/pid54777/study1/view1_frontal.jpg
# 6    test/pid54251/study2/view1_frontal.jpg
# 7    test/pid54251/study2/view2_lateral.jpg
# 8    test/pid54251/study1/view1_frontal.jpg
# 9    test/pid54251/study1/view2_lateral.jpg
# Name: Path, dtype: object

# %%
prefix = '/groups/CS156b/data/'
dest_dir = '/groups/CS156b/2024/BroadBahnMi/data/test/images/'
for i, path in enumerate(test_imgs_paths):
    full_path = prefix + path
    shutil.copy(full_path, dest_dir + f'img{i}.jpg')
